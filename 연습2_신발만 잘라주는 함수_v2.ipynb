# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.segmentation import clear_border
import skimage.morphology as mp
import scipy.ndimage.morphology as sm

# %%
# 원본 이미지
img = cv2.imread('/content/drive/MyDrive/GoogleColab/MiniProject/sample_image/1692171_1_500.jpg')
# 흑백 이미지
img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img.shape)
# Out:
# (500, 500, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img_grey, 'gray')

# %%
th,img1 = cv2.threshold(img,0,255,cv2.THRESH_OTSU)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-31999a4bb2a8> in <module>()
# ----> 1 th,img1 = cv2.threshold(img,0,255,cv2.THRESH_OTSU)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/thresh.cpp:1527: error: (-215:Assertion failed) src.type() == CV_8UC1 in function 'threshold'
